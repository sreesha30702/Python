# %%
#write a p python program to printout all colors from color set 1 not contain in color set  2
color_set1 = {"red","yellow","blue","green"}
color_set2 = {"white","black","yellow","red"}
result = color_set1-color_set2
print("Colors in color set 1 but not contain in set 2:",result)
# Out:
# Colors in color set 1 but not contain in set 2: {'green', 'blue'}

# %%
#write a python program to printout all colors from color set 1 andcolor set 2
color_set1 = {"red","yellow","blue","green"}
color_set2 = {"white","black","yellow","red"}
result = color_set1 |color_set2
print("enter all colors from color set 1 and color set 2:",result)
# Out:
# enter all colors from color set 1 and color set 2: {'white', 'red', 'black', 'green', 'blue', 'yellow'}
