# %%
#write a p python program to printout all colors from color set 1 not contain in color set  2
color_set1 = set(input("Enter colors for set 1: ").split())
color_set2 = set(input("Enter colors for set 2: ").split())

result = color_set1 - color_set2

print("Colors in color set 1 but not in set 2:", result)
# Out:
# Enter colors for set 1:  blue,green,yellow,black
# Enter colors for set 2:  white,orange,red,yellow
# Colors in color set 1 but not in set 2: {'blue,green,yellow,black'}

# %%
#write a python program to printout all colors from color set 1 andcolor set 2color_set1 = set(input("Enter colors for set 1: ").split())
color_set2 = set(input("Enter colors for set 2: ").split())

result = color_set1 | color_set2

print("All colors from color set 1 and color set 2:", result)
# Out:
# Enter colors for set 1:  blue,green,yellolw,blue
# Enter colors for set 2:  yellow,white,red,green
# All colors from color set 1 and color set 2: {'blue,green,yellolw,blue', 'yellow,white,red,green'}
