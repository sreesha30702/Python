# %%
#create a list of colors from coma_seperated color names entered by user.display first and last colors
colors = input("Enter colors:").split(",")
print("First:",colors[0])
print("Last:",colors[-1])
# Out:
# Enter colors: red,green,blue
# First: red
# Last: blue

# %%
#a python program to accept a filename from the user,print extenswion of that
filename=input("Enter filename:")
print(filename.split(".")[-1])
# Out:
# Enter filename: photo.jpg
# jpg

# %%
#a python program which accept a sequence of comma separated numbers from user and generate a list with those nos & find sum of all items in list
nums=input("Enter numbers: ").split(',')
numbers =[int(n) for n in nums]
print(numbers)
print(sum(numbers))
# Out:
# Enter numbers:  1,2,3,4
# [1, 2, 3, 4]
# 10
