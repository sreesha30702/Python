# %%
#write apython program to accept 5 students name and roll numberand map it into dictionary
students = {}
for i in range(5):
    name = input("Enter student name:")
    roll =int (input("Enter roll number:"))
    students[roll] = name
    ascending = dict(sorted(students.items()))
    descending = dict(sorted(students.items(),reverse=True))
    print("Original dictionary:",students)
    print("Ascending Order:",ascending)
    print("Descending Order:",descending)
# Out:
# Enter student name: anu
# Enter roll number: 17
# Original dictionary: {17: 'anu'}
# Ascending Order: {17: 'anu'}
# Descending Order: {17: 'anu'}
# Enter student name: arun
# Enter roll number: 37
# Original dictionary: {17: 'anu', 37: 'arun'}
# Ascending Order: {17: 'anu', 37: 'arun'}
# Descending Order: {37: 'arun', 17: 'anu'}
# Enter student name: liya
# Enter roll number: 24
# Original dictionary: {17: 'anu', 37: 'arun', 24: 'liya'}
# Ascending Order: {17: 'anu', 24: 'liya', 37: 'arun'}
# Descending Order: {37: 'arun', 24: 'liya', 17: 'anu'}
# Enter student name: appu
# Enter roll number: 10
# Original dictionary: {17: 'anu', 37: 'arun', 24: 'liya', 10: 'appu'}
# Ascending Order: {10: 'appu', 17: 'anu', 24: 'liya', 37: 'arun'}
# Descending Order: {37: 'arun', 24: 'liya', 17: 'anu', 10: 'appu'}
# Enter student name: riya
# Enter roll number: 3
# Original dictionary: {17: 'anu', 37: 'arun', 24: 'liya', 10: 'appu', 3: 'riya'}
# Ascending Order: {3: 'riya', 10: 'appu', 17: 'anu', 24: 'liya', 37: 'arun'}
# Descending Order: {37: 'arun', 24: 'liya', 17: 'anu', 10: 'appu', 3: 'riya'}
