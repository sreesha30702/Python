# %%
#write apython program to accept 5 students name and roll numberand map it into dictionary
students = {}

name1 = input("Enter student name:")
roll1 =int (input("Enter roll number:"))
students[roll1] = name1
name2 = input("Enter student name:")
roll2 =int (input("Enter roll number:"))
students[roll2] = name2
name3 = input("Enter student name:")
roll3 =int (input("Enter roll number:"))
students[roll3] = name3
name4 = input("Enter student name:")
roll4 =int (input("Enter roll number:"))
students[roll4] = name4
name5 = input("Enter student name:")
roll5 =int (input("Enter roll number:"))
students[roll5] = name5
ascending = dict(sorted(students.items()))
descending = dict(sorted(students.items(),reverse=True))
print("Original dictionary:",students)
print("Ascending Order:",ascending)
print("Descending Order:",descending)
# Out:
# Enter student name: sree
# Enter roll number: 37
# Enter student name: liya
# Enter roll number: 22
# Enter student name: theju
# Enter roll number: 39
# Enter student name: shaika
# Enter roll number: 11
# Enter student name: richu
# Enter roll number: 28
# Original dictionary: {37: 'sree', 22: 'liya', 39: 'theju', 11: 'shaika', 28: 'richu'}
# Ascending Order: {11: 'shaika', 22: 'liya', 28: 'richu', 37: 'sree', 39: 'theju'}
# Descending Order: {39: 'theju', 37: 'sree', 28: 'richu', 22: 'liya', 11: 'shaika'}

# %%
#python program to accept 2 dictionaries (dic1 contains 3 student name and roll number and dic2 contains 2 student names and roll number)Merge to dictionaries and display it(use update())
roll=list(map(int,input("Enter the Roll Number of 3 students:").split(",")))
name=input("Enter the Name of 3 students:").split(",")
d1=dict(zip(roll,name))
print("Dictionary 1:",d1)
roll=list(map(int,input("Enter the Roll Number of 2 students:").split(",")))
name=input("Enter the Name of 2 students:").split(",")
d2=dict(zip(roll,name))
print("Dictionary 2:",d2)
d1.update(d2)
print("Merged Dictionary:",d1)
# Out:
# Enter the Roll Number of 3 students: 37,12,5
# Enter the Name of 3 students: sree,liya,riya
# Dictionary 1: {37: 'sree', 12: 'liya', 5: 'riya'}
# Enter the Roll Number of 2 students: 22,11
# Enter the Name of 2 students: kiran,achu
# Dictionary 2: {22: 'kiran', 11: 'achu'}
# Merged Dictionary: {37: 'sree', 12: 'liya', 5: 'riya', 22: 'kiran', 11: 'achu'}
