# %%
#create a list of colors from coma_separated color names entered by user.display first and last colors
colors=input("enter name of colors seperated by comma:").split(",")
print("first color:",colors[0])
print("last color:",colors[-1])
# Out:
# enter name of colors seperated by comma: red,blue,white,yellow
# first color: red
# last color: yellow

# %%
#a pytghon program to accept a filename from user
filename=input("enter filename:")
extension=filename.split(".")[-1]
print("extention:",extension)
# Out:
# enter filename: py
# extention: py

# %%
# a python program which accept a  sequence
a=input("enter a numbers seperated by commas")
b=a.split(",")
b=[int(x) for x in b]
print("List:",b)
print("sum:",sum(b))
# Out:
# enter a numbers seperated by commas 10,20,30,40
# List: [10, 20, 30, 40]
# sum: 100
